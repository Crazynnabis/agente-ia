# %%
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.agente_youtube import analizar_video_financiero

resultado = analizar_video_financiero(
    video_id="fvGLnthJDsg",
    titulo="Is Stock Picking a Loser's Game?"
)

print(f"Video: {resultado['video_id']}")
print(f"Chars extraídos: {resultado.get('transcripcion_chars', 0)}")
print(f"\nAnálisis:")
print(resultado.get('analisis', resultado.get('error')))
# Out:
# [agente_youtube] Extrayendo transcripción de fvGLnthJDsg...
# Video: fvGLnthJDsg
# Chars extraídos: 0
#
# Análisis:
# None

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Nueva sintaxis de la versión actual
ytt = YouTubeTranscriptApi()
info = ytt.list("fvGLnthJDsg")
for t in info:
    print(t)
# Out:
# en ("English")[TRANSLATABLE]

# %%
import importlib
import agente_financiero.agente_youtube as ay
importlib.reload(ay)

resultado = ay.analizar_video_financiero(
    video_id="fvGLnthJDsg",
    titulo="Is Stock Picking a Loser's Game?"
)

print(f"Chars extraídos: {resultado.get('transcripcion_chars', 0)}")
print(f"\nAnálisis:")
print(resultado.get('analisis', resultado.get('error')))
# Out:
# [agente_youtube] Extrayendo transcripción de fvGLnthJDsg...
# Chars extraídos: 0
#
# Análisis:
# None

# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt = YouTubeTranscriptApi()
transcript = ytt.fetch("fvGLnthJDsg")
print(type(transcript))
print(transcript[:3])
# Out:
# <class 'youtube_transcript_api._transcripts.FetchedTranscript'>
# [FetchedTranscriptSnippet(text='- I generally assume that most', start=0.19, duration=1.188), FetchedTranscriptSnippet(text='of you watching these\nvideos are already fully', start=1.378, duration=2.942), FetchedTranscriptSnippet(text='on board with the idea that\nindex investing makes sense.', start=4.32, duration=3.81)]

# %%
importlib.reload(ay)

resultado = ay.analizar_video_financiero(
    video_id="fvGLnthJDsg",
    titulo="Is Stock Picking a Loser's Game?"
)

print(f"Chars extraídos: {resultado.get('transcripcion_chars', 0)}")
print(f"\nAnálisis:")
print(resultado.get('analisis', resultado.get('error')))
# Out:
# [agente_youtube] Extrayendo transcripción de fvGLnthJDsg...
# [agente_youtube] Analizando con Ollama...
# Chars extraídos: 8443
#
# Análisis:
# **Activos mencionados:**
#
# * Acciones
# * ETFs (Exchange-Traded Funds)
# * Fondos mutuales
# * Activo (investigación y gestión activa)
#
# **Tendencia recomendada:**
# Neutral, a favor de la inversión en fondos índices.
#
# **Razones principales:**
#
# 1. La investigación de Vanguard muestra que más del 50% de los gestores activos no superan el rendimiento del índice en periodos de caída del mercado.
# 2. El riesgo introducido por la gestión activa es mayor que el riesgo del mercado, ya que introduce un elemento adicional de riesgo que no está "preciado".
# 3. La investigación muestra que los fondos índices ofrecen una inversión relativamente segura y estable.
#
# **Nivel de confianza:**
# Alto (85%), debido a la evidencia empírica y la lógica presentada por el autor.
#
# **Horizonte temporal mencionado:**
# ...

# %%
import importlib
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.agente_sentimiento import analizar_sentimiento_mercado

resultado = analizar_sentimiento_mercado()

print(f"Fear & Greed: {resultado['fear_greed']}")
print(f"\nAnálisis:")
print(resultado['analisis'])
# Out:
# [agente_sentimiento] Obteniendo Fear & Greed Index...
# [agente_sentimiento] Scrapeando Reddit investing...
# [agente_sentimiento] Scrapeando crypto trending...
# [agente_sentimiento] Analizando con Ollama...
# Fear & Greed: {'valor_hoy': 47, 'clasificacion': 'Neutral', 'promedio_7dias': 43, 'tendencia': 'mejorando'}
#
# Análisis:
# **Informe de Sentimiento del Mercado**
#
# **Sentimiento General del Mercado**
# El Fear & Greed Index se encuentra en un estado **Neutral**, con una puntuación de 47, lo que indica un equilibrio entre el miedo y la codicia en el mercado. Aunque se ha mejorado ligeramente desde la semana anterior (43), sigue siendo un nivel relativamente estable.
#
# **Nivel de Miedo o Codicia Predominante**
# En este caso, no hay una tendencia clara hacia el miedo o la codicia dominante en el mercado. El Fear & Greed Index se encuentra en un estado neutral, lo que sugiere que los inversores están adoptando una postura cautelosa.
#
# ...

# %%
from agente_financiero.agente_macro import analizar_contexto_macro

resultado = analizar_contexto_macro()

print(f"Noticias procesadas: {resultado['noticias_count']}")
print(f"\nAnálisis macro:")
print(resultado['analisis'])
# Out:
# [agente_macro] Obteniendo noticias macro con NewsAPI...
# [agente_macro] Scrapeando BBC geopolítica...
# [agente_macro] Analizando impacto en mercados con Ollama...
# Noticias procesadas: 9
#
# Análisis macro:
# **Reporte Macroecoíomico y Geopolítico**
#
# **Eventos Geopolíticos con Impacto en Mercados**
#
# 1. **Corrupción en Nepal**: La estabilidad del país es amenazada por la corrupción, lo que podría tener un impacto en la región.
# 2. **UAE saliendo de OPEC**: La decisión del Emiratos Árabes Unidos de dejar el cartel puede afectar los precios de la energía y la economía global.
# 3. **Conflito entre Irán e Irak**: El vicepresidente de la Boston Fed advierte que el conflicto podría alimentar la inflación, lo que podría llevar a decisiones más expansivas por parte del Banco Central.
#
# **Decisiones de Bancos Centrales**
#
# 1. **FED**: La decisión del Federal Reserve sobre las tasas de interés seguirá siendo influenciada por los datos económicos y el conflicto entre Irán e Irak.
# ...

# %%
from agente_financiero.agente_historico import analizar_historico_completo

resultado = analizar_historico_completo()

print("Análisis histórico:")
print(resultado['analisis'])
# Out:
# [agente_historico] Analizando AAPL...
# [agente_historico] Analizando NVDA...
# [agente_historico] Analizando MSFT...
# [agente_historico] Analizando TSLA...
# [agente_historico] Analizando SPY...
# [agente_historico] Analizando QQQ...
# [agente_historico] Analizando BTC-USD...
# [agente_historico] Analizando ETH-USD...
# [agente_historico] Analizando GC=F...
# [agente_historico] Analizando CL=F...
# [agente_historico] Generando análisis con Ollama...
# Análisis histórico:
# **Análisis de mercados y recomendaciones**
#
# **Top 3 activos con mejor perfil riesgo/retorno**
#
# 1. **NVDA**: Con un rendimiento anual del 83,39% y una volatilidad relativamente baja (48,89%), NVDA se presenta como un activo con un excelente perfil de riesgo/retorno.
# 2. **AAPL**: Aunque su drawdown es significativo (-33,36%), AAPL ha demostrado un rendimiento anual del 49,17% y una volatilidad moderada (25,8%).
# ...

# %%
import importlib
import agente_financiero.agente_fundamental as af
importlib.reload(af)

resultado = af.analizar_fundamental_completo()
print(resultado['analisis'])
# Out:
# [agente_fundamental] Analizando AAPL...
# [agente_fundamental] Analizando NVDA...
# [agente_fundamental] Analizando MSFT...
# [agente_fundamental] Analizando TSLA...
# [agente_fundamental] Analizando SPY...
# [agente_fundamental] Analizando AMZN...
# [agente_fundamental] Analizando GOOGL...
# [agente_fundamental] Analizando META...
# [agente_fundamental] Analizando con Ollama...
# **Análisis Fundamental**
#
# Después de analizar los datos, te presento mi evaluación:
#
# 1. **Top 3 empresas infravaloradas**:
#    - TSLA (PE=400.3271): A pesar del fuerte crecimiento, su valorización se encuentra más allá del rango promedio.
#    - META: Su P/E ratio es relativamente bajo en comparación con sus fundamentos de crecimiento y margen de ganancia.
#    - GOOGL (PE=30.572083): Aunque su crecimiento ha sido consistente, su valorización se encuentra un poco por debajo del rango promedio.
#
# 2. **Mejor salud financiera**:
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.agente_digestor import ejecutar_ciclo_completo

resultado = ejecutar_ciclo_completo()
# Out:
# === INICIANDO CICLO COMPLETO DE ANALISIS ===
#
# [1/5] Noticias financieras...
# [2/5] Sentimiento de mercado...
# [agente_sentimiento] Obteniendo Fear & Greed Index...
# [agente_sentimiento] Scrapeando Reddit investing...
# [agente_sentimiento] Scrapeando crypto trending...
# [agente_sentimiento] Analizando con Ollama...
# [3/5] Contexto macro...
# [agente_macro] Obteniendo noticias macro con NewsAPI...
# [agente_macro] Scrapeando BBC geopolítica...
# [agente_macro] Analizando impacto en mercados con Ollama...
# [4/5] Analisis historico...
# [agente_historico] Analizando AAPL...
# [agente_historico] Analizando NVDA...
# [agente_historico] Analizando MSFT...
# [agente_historico] Analizando TSLA...
# [agente_historico] Analizando SPY...
# [agente_historico] Analizando QQQ...
# [agente_historico] Analizando BTC-USD...
# [agente_historico] Analizando ETH-USD...
# [agente_historico] Analizando GC=F...
# [agente_historico] Analizando CL=F...
# ...

# %%
import importlib
import agente_financiero.agente_velas as av
importlib.reload(av)

resultado = av.analizar_oportunidades()

print(f"Oportunidades: {len(resultado['oportunidades'])}")
print(f"Alertas: {len(resultado['alertas'])}")
print(f"\nRecomendaciones:")
print(resultado['recomendaciones'])
# Out:
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con Ollama...
# Oportunidades: 1
# Alertas: 4
#
# Recomendaciones:
# **ANALISIS Y RECOMENDACIONES**
#
# La situación actual es la siguiente:
#
# * La BTCUSDT está con un patrón de **ENVOLVENTE_ALCISTA**, lo que sugiere que el precio puede seguir subiendo.
# * El RSI se encuentra en 54.6, lo que indica una sobrecompra.
# * Hay varias alertas de venta en diferentes criptomonedas, incluyendo BTCUSDT y ETHUSDT.
#
# **RECOMENDACIONES**
#
# 1. **BTCUSDT - COMPRA**
# 	* Precio de entrada: $81340.0
# 	* Stop loss sugerido: $80000.0 (10% por debajo del precio de entrada)
# 	* Take profit sugerido: $82000.0 (5% por encima del precio de entrada)
# 	* Nivel de confianza: Alta (90%)
# 2. **ETHUSDT - VENTA**
# 	* Precio de entrada: $2355.05
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.agente_indicadores import analizar_indicadores_completo

resultados = analizar_indicadores_completo()

for r in resultados:
    print(f"\n{'='*50}")
    print(f"SIMBOLO: {r['simbolo']}")
    print(f"SEÑAL: {r['señal']} | CONFIANZA: {r['confianza']}%")
    print(f"Alcistas: {r['puntos_alcistas']} | Bajistas: {r['puntos_bajistas']}")
    print(f"MACD: {r['macd']}")
    print(f"Estocástico: {r['estocastico']}")
    print(f"VWAP: {r['vwap']['posicion']} | distancia: {r['vwap']['distancia_pct']}%")
    print(f"OBV: {r['obv']['tendencia']} | {r['obv']['aceleracion']}")
    print(f"ATR stop_largo: {r['atr']['stop_loss_largo']} | TP1: {r['atr']['take_profit_1r']}")
    print(f"Williams %R: {r['williams_r']}")
# Out:
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT
# SEÑAL: COMPRAR | CONFIANZA: 60%
# Alcistas: 3 | Bajistas: 2
# MACD: {'macd': 53.5053, 'signal': 62.2061, 'histograma': -8.7008, 'divergencia': 'alcista_acelerando', 'cruce': None}
# Estocástico: {'k': 81.5, 'd': 64.9, 'señal': 'neutral'}
# VWAP: sobre_vwap_ALCISTA | distancia: 0.558%
# OBV: acumulacion | desacelerando
# ATR stop_largo: 81276.7229 | TP1: 81559.7029
# Williams %R: {'williams_r': -18.5, 'señal': 'sobrecomprado_VENTA'}
#
# ...
# SIMBOLO: ETHUSDT
# SEÑAL: COMPRAR | CONFIANZA: 100%
# Alcistas: 3 | Bajistas: 0
# MACD: {'macd': 4.2511, 'signal': 4.0789, 'histograma': 0.1722, 'divergencia': 'alcista_acelerando', 'cruce': None}
# Estocástico: {'k': 78.0, 'd': 69.9, 'señal': 'neutral'}
# VWAP: sobre_vwap_ALCISTA | distancia: 0.744%
# OBV: acumulacion | desacelerando
# ...

# %%
from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico

resultado = ejecutar_ciclo_tecnico()

print(f"\nSeñales fuertes: {len(resultado['señales_fuertes'])}")
print(f"Contradicciones: {len(resultado['contradicciones'])}")
print(f"\n=== DECISIONES EJECUTABLES ===")
print(resultado['decisiones'])
# Out:
# [digestor_tecnico] Ciclo tecnico 11:50:37
# [1/2] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con Ollama...
# [2/2] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [digestor_tecnico] Generando decision ejecutable...
#
# Señales fuertes: 3
# Contradicciones: 1
#
# === DECISIONES EJECUTABLES ===
# DECISION_1:
# - ACCION: VENDER
# - SIMBOLO: BTCUSDT
# - PRECIO_ENTRADA: 81450.0
# - STOP_LOSS: 81324.4286
# - TAKE_PROFIT_1: 81617.4286
# - TAKE_PROFIT_2: 81701.1429
# - CONFIANZA: 37%
# - RAZON: La baja contracción en el gráfico indica una tendencia a la baja y la confianza es baja, lo que sugiere que es momento de vender.
# - HORIZENTE: 5min

# %%
from agente_financiero.agente_orderflow import analizar_todos_activos

resultados = analizar_todos_activos()

for r in resultados:
    print(f"\n{'='*50}")
    print(f"SIMBOLO: {r['simbolo']} | PRECIO: {r['precio']}")
    print(f"SEÑAL: {r['señal']} | FUERZA: {r['fuerza']}")
    print(f"Ratio compra/venta: {r['ratio_compra_venta']}")
    print(f"Delta trades: {r['delta_pct']}%")
    print(f"Imbalance: {r['imbalance_pct']}%")
    print(f"Pared alerta: {r.get('pared_alerta', 'ninguna')}")
# Out:
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT | PRECIO: 81450.15
# SEÑAL: PRESION_COMPRADORA_FUERTE | FUERZA: alta
# Ratio compra/venta: 4.294
# Delta trades: 64.81%
# Imbalance: 62.22%
# Pared alerta: SOPORTE_FUERTE en 81450.15 (2.82 unidades)
#
# ...
# SIMBOLO: ETHUSDT | PRECIO: 2363.12
# SEÑAL: PRESION_COMPRADORA_FUERTE | FUERZA: alta
# Ratio compra/venta: 1.908
# Delta trades: 13.98%
# Imbalance: 31.24%
# Pared alerta: SOPORTE_FUERTE en 2363.1 (64.09 unidades)
#
# ...
# SIMBOLO: SOLUSDT | PRECIO: 96.37
# SEÑAL: PRESION_VENDEDORA_FUERTE | FUERZA: alta
# Ratio compra/venta: 0.584
# Delta trades: -15.97%
# Imbalance: -26.29%
# Pared alerta: SOPORTE_FUERTE en 96.31 (607.61 unidades)
#
# ...
# SIMBOLO: BNBUSDT | PRECIO: 660.56
# SEÑAL: NEUTRAL | FUERZA: debil
# Ratio compra/venta: 0.949
# Delta trades: -72.23%
# Imbalance: -2.6%
# ...

# %%
from agente_financiero.agente_niveles import analizar_niveles_completo

for simbolo in ["BTCUSDT", "ETHUSDT"]:
    r = analizar_niveles_completo(simbolo)
    zd = r["zonas_diario"]
    print(f"\n{'='*50}")
    print(f"SIMBOLO: {r['simbolo']} | PRECIO: {r['precio_actual']}")
    print(f"Contexto: {zd.get('contexto', 'N/A')}")
    print(f"Dist soporte: {zd.get('dist_soporte_pct', 'N/A')}%")
    print(f"Dist resistencia: {zd.get('dist_resistencia_pct', 'N/A')}%")
    print(f"Fibonacci cercano: {r.get('fib_cercano', 'N/A')}")
    print(f"Soporte cercano: {zd.get('soporte_cercano', 'N/A')}")
    print(f"Resistencia cercana: {zd.get('resistencia_cercana', 'N/A')}")
# Out:
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
#
# ...
# SIMBOLO: BTCUSDT | PRECIO: 81400.01
# Contexto: SIN_REFERENCIA_clara
# Dist soporte: None%
# Dist resistencia: 7.94%
# Fibonacci cercano: ('0.0', 82850.0)
# Soporte cercano: None
# Resistencia cercana: {'precio_base': np.float64(87863.42), 'precio_tope': np.float64(88175.98), 'fuerza': np.float64(1.24), 'fecha': '2025-12-16', 'toques': 29}
# [agente_niveles] Analizando ETHUSDT diario...
# [agente_niveles] Analizando ETHUSDT 4h...
#
# ...
# SIMBOLO: ETHUSDT | PRECIO: 2363.55
# Contexto: CERCA_SOPORTE_oportunidad
# Dist soporte: 3.07%
# Dist resistencia: 80.26%
# Fibonacci cercano: ('0.382', 2354.1644)
# Soporte cercano: {'precio_base': np.float64(2280.1), 'precio_tope': np.float64(2291.06), 'fuerza': np.float64(1.81), 'fecha': '2026-05-07', 'toques': 18}
# ...

# %%
import importlib
import agente_financiero.agente_velas as av
import agente_financiero.digestor_tecnico as dt
importlib.reload(av)
importlib.reload(dt)

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico

resultado = await ejecutar_ciclo_tecnico()

print(f"\nModelo usado: {resultado['modelo']}")
print(f"Señales fuertes: {len(resultado['señales_fuertes'])}")
print(f"\n=== DECISIONES ===")
print(resultado['decisiones'])
# Out:
# [digestor_tecnico] Ciclo tecnico 12:37:56
# [1/2] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/2] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [digestor_tecnico] Generando decisiones ejecutables con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
#
# Modelo usado: llama3.2
# Señales fuertes: 1
#
# === DECISIONES ===
# DECISION_1:
# - ACCION: COMPRAR
# - SIMBOLO: BTCUSDT
# - PRECIO_ENTRADA: 81310.44
# - STOP_LOSS: 81185.3689
# - TAKE_PROFIT_1: 81477.2014
# - TAKE_PROFIT_2: 81560.5821
# - CONFIANZA: 86%
# ...

# %%
import importlib
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.agente_correlaciones import analizar_correlaciones_completo

resultado = await analizar_correlaciones_completo()

print(f"Modelo: {resultado['modelo']}")
print(f"\nPares alta correlacion: {len(resultado['pares_alta_correlacion'])}")
for p in resultado['pares_alta_correlacion'][:5]:
    print(f"  {p['par']}: {p['correlacion']} ({p['tipo']})")

print(f"\nDivergencias detectadas: {len(resultado['divergencias'])}")
for d in resultado['divergencias']:
    print(f"  {d['par']}: {d['estado']}")

print(f"\n=== ANALISIS ===")
print(resultado['analisis'])
# Out:
# [agente_correlaciones] Descargando datos...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 9
#       5 from agente_financiero.agente_correlaciones import analizar_correlaciones_completo
#       6
#       7 resultado = await analizar_correlaciones_completo()
#       8
# ----> 9 print(f"Modelo: {resultado['modelo']}")
#      10 print(f"\nPares alta correlacion: {len(resultado['pares_alta_correlacion'])}")
#      11 for p in resultado['pares_alta_correlacion'][:5]:
#      12     print(f"  {p['par']}: {p['correlacion']} ({p['tipo']})")
#
# KeyError: 'modelo'

# %%
from agente_financiero.agente_correlaciones import obtener_datos_multiples

simbolos = ["BTC-USD", "ETH-USD", "SPY", "QQQ", "GC=F", "AAPL", "NVDA"]
df = obtener_datos_multiples(simbolos, dias=60)

print(f"Filas: {len(df)}")
print(f"Columnas disponibles: {list(df.columns)}")
# Out:
# Filas: 0
# Columnas disponibles: ['BTC-USD', 'ETH-USD', 'SPY', 'QQQ', 'GC=F', 'AAPL', 'NVDA']

# %%
import yfinance as yf
from datetime import datetime, timedelta

fin = datetime.now()
inicio = fin - timedelta(days=60)

dfs = {}
for simbolo in ["BTC-USD", "ETH-USD", "SPY", "AAPL"]:
    df = yf.Ticker(simbolo).history(start=inicio, end=fin)
    print(f"{simbolo}: {len(df)} filas, fechas {df.index[0].date() if len(df)>0 else 'N/A'} → {df.index[-1].date() if len(df)>0 else 'N/A'}")
    dfs[simbolo] = df["Close"]

import pandas as pd
combined = pd.DataFrame(dfs)
print(f"\nSin dropna: {len(combined)} filas")
print(f"Con dropna: {len(combined.dropna())} filas")
print(f"\nNulos por columna:\n{combined.isnull().sum()}")
# Out:
# BTC-USD: 61 filas, fechas 2026-03-11 → 2026-05-10
# ETH-USD: 61 filas, fechas 2026-03-11 → 2026-05-10
# SPY: 42 filas, fechas 2026-03-11 → 2026-05-08
# AAPL: 42 filas, fechas 2026-03-11 → 2026-05-08
#
# Sin dropna: 103 filas
# Con dropna: 0 filas
#
# Nulos por columna:
# BTC-USD    42
# ETH-USD    42
# SPY        61
# AAPL       61
# dtype: int64

# %%
import importlib
import agente_financiero.agente_correlaciones as ac
importlib.reload(ac)

resultado = await ac.analizar_correlaciones_completo()

print(f"Modelo: {resultado.get('modelo', 'N/A')}")
print(f"Pares: {len(resultado.get('pares_alta_correlacion', []))}")
print(f"\n=== ANALISIS ===")
print(resultado.get('analisis', resultado.get('error', 'Sin datos')))
# Out:
# [agente_correlaciones] Descargando datos...
# [agente_correlaciones] Calculando matriz de correlacion...
# [agente_correlaciones] Detectando divergencias...
# [agente_correlaciones] Analizando lider/seguidor...
# [agente_correlaciones] Generando analisis con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# Modelo: llama3.2
# Pares: 17
#
# === ANALISIS ===
# **Análisis de Correlaciones y Divergencias**
#
# **Oportunidades de Arbitraje o Anticipación Detectadas:**
#
# 1. **GC=F/DX-Y.NYB**: La correlación rompió a la baja, lo que indica un posible movimiento inverso en el mercado de commodities. Esta divergencia puede generar una oportunidad para tomar una posición corta.
# 2. **BTC-USD/ETH-USD**: Aunque la correlación es alta y positiva, se puede observar una ligera disminución reciente de la correlación (-0.076). Esto podría indicar que BTC-USD está empezando a liderar a ETH-USD en términos de movimiento.
#
# **Activos que Están Divergiendo de su Correlación Histórica:**
# ...

# %%
from agente_financiero.agente_onchain import analizar_onchain_completo

resultado = await analizar_onchain_completo()

print(f"Modelo: {resultado['modelo']}")
print(f"\nBTC precio: ${resultado['btc'].get('precio_btc', 'N/A')}")
print(f"Fee rapido: {resultado['btc'].get('fee_rapido', 'N/A')} sat/vB")
print(f"Dominancia BTC: {resultado['flujo'].get('dominancia_btc', 'N/A')}%")
print(f"\nSeñales detectadas:")
for s in resultado['señales'].get('señales', []):
    print(f"  - {s}")
print(f"\n=== ANALISIS ON-CHAIN ===")
print(resultado['analisis'])
# Out:
# [agente_onchain] Obteniendo datos BTC blockchain...
# [agente_onchain] Obteniendo flujo de exchanges y dominancia...
# [agente_onchain] Obteniendo datos ETH...
# [agente_onchain] Interpretando señales on-chain...
# [agente_onchain] Generando analisis con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# Modelo: llama3.2
#
# BTC precio: $81224.55
# Fee rapido: 1 sat/vB
# Dominancia BTC: 58.06%
#
# Señales detectadas:
#   - BAJA_ACTIVIDAD_BTC — red poco congestionada, posible acumulacion silenciosa
#   - DOMINANCIA_BTC_ALTA (58.06%) — capital fluyendo a BTC, altcoins en riesgo
#   - VOLUMEN_BAJO (2.44% del mcap) — mercado consolidando, esperar ruptura
#
# === ANALISIS ON-CHAIN ===
# **Análisis on-chain y recomendación**
#
# **Estado actual de la red:**
# La red de Bitcoin se encuentra en un estado de baja actividad, lo que podría sugerir una acumulación silenciosa. La congestionación de la red es baja, lo que podría ser beneficioso para los compradores.
#
# ...

# %%
import importlib
import agente_financiero.digestor_tecnico as dt
importlib.reload(dt)

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico

resultado = await ejecutar_ciclo_tecnico()

print(f"Modelo: {resultado['modelo']}")
print(f"Señales fuertes: {len(resultado['señales_fuertes'])}")
print(f"\n=== TABLA DE CONFLUENCIA ===")
for t in resultado['tabla']:
    print(f"{t['simbolo']}: {t['señal_final']} | confianza={t['confianza_final']}% | votos C={t['votos_compra']} V={t['votos_venta']}")

print(f"\n=== DECISIONES EJECUTABLES ===")
print(resultado['decisiones'])
# Out:
# [digestor_tecnico] Ciclo tecnico 13:25:53
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/5] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [3/5] Analizando order flow...
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
# [4/5] Analizando niveles clave...
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
# [agente_niveles] Analizando ETHUSDT diario...
# [agente_niveles] Analizando ETHUSDT 4h...
# ...

# %%
import importlib
import agente_financiero.agente_indicadores as ai
import agente_financiero.digestor_tecnico as dt
importlib.reload(ai)
importlib.reload(dt)

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico

resultado = await ejecutar_ciclo_tecnico()

print(f"Modelo: {resultado['modelo']}")
print(f"\n=== TABLA DE CONFLUENCIA ===")
for t in resultado['tabla']:
    distancia_sl  = round(abs(t['precio'] - t['stop_loss']) / t['precio'] * 100, 2)
    distancia_tp1 = round(abs(t['take_profit_1'] - t['precio']) / t['precio'] * 100, 2)
    ratio = round(distancia_tp1 / distancia_sl, 2) if distancia_sl > 0 else 0
    print(f"{t['simbolo']}: {t['señal_final']} | conf={t['confianza_final']}% | "
          f"SL={distancia_sl}% | TP1={distancia_tp1}% | ratio R/B={ratio}x")

print(f"\n=== DECISIONES ===")
print(resultado['decisiones'])
# Out:
# [digestor_tecnico] Ciclo tecnico 13:37:14
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/5] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [3/5] Analizando order flow...
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
# [4/5] Analizando niveles clave...
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
# [agente_niveles] Analizando ETHUSDT diario...
# [agente_niveles] Analizando ETHUSDT 4h...
# ...

# %%
import importlib
import agente_financiero.agente_indicadores as ai
import agente_financiero.digestor_tecnico as dt
importlib.reload(ai)
importlib.reload(dt)

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico

resultado = await ejecutar_ciclo_tecnico()

print(f"Modelo: {resultado['modelo']}")
print(f"\n=== TABLA DE CONFLUENCIA ===")
for t in resultado['tabla']:
    distancia_sl  = round(abs(t['precio'] - t['stop_loss']) / t['precio'] * 100, 2)
    distancia_tp1 = round(abs(t['take_profit_1'] - t['precio']) / t['precio'] * 100, 2)
    ratio = round(distancia_tp1 / distancia_sl, 2) if distancia_sl > 0 else 0
    print(f"{t['simbolo']}: {t['señal_final']} | conf={t['confianza_final']}% | "
          f"confluencia={t['confluencia']} | "
          f"SL={distancia_sl}% | TP1={distancia_tp1}% | ratio R/B={ratio}x")

print(f"\n=== DECISIONES ===")
print(resultado['decisiones'])
# Out:
# [digestor_tecnico] Ciclo tecnico 13:51:00
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/5] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [3/5] Analizando order flow...
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
# [4/5] Analizando niveles clave...
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
# [agente_niveles] Analizando ETHUSDT diario...
# [agente_niveles] Analizando ETHUSDT 4h...
# ...

# %%
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.gestion_riesgo import gestor
from agente_financiero.filtro_tendencia import analizar_tendencias_multiples, filtrar_señal_por_tendencia

# Prueba 1: Tendencias mayores
print("=== TENDENCIAS MAYORES ===")
activos = ["BTCUSDT", "ETHUSDT", "SOLUSDT", "BNBUSDT"]
tendencias = analizar_tendencias_multiples(activos)

for simbolo, t in tendencias.items():
    print(f"\n{simbolo}:")
    print(f"  Tendencia mayor: {t['tendencia_mayor']}")
    print(f"  Votos alcista: {t['votos_alcista']} | bajista: {t['votos_bajista']}")
    print(f"  Alineada compra: {t['alineada_compra']} | venta: {t['alineada_venta']}")
    for tf, datos in t['timeframes'].items():
        print(f"  {tf}: {datos.get('tendencia','N/A')}")

# Prueba 2: Gestión de riesgo
print("\n=== GESTION DE RIESGO ===")
señal_prueba = {
    "simbolo":        "BTCUSDT",
    "precio":         81400.0,
    "stop_loss":      81200.0,
    "take_profit_1":  81800.0,
    "confianza_final": 85,
    "confluencia":    "ALTA",
    "señal_final":    "COMPRAR"
}
validacion = gestor.validar_señal(señal_prueba)
print(f"Señal aprobada: {validacion['aprobada']}")
print(f"Errores: {validacion['errores']}")
print(f"Warnings: {validacion['warnings']}")
print(f"Horario optimo: {validacion['horario']['horario_optimo']}")
if validacion.get('tamaño'):
    t = validacion['tamaño']
    print(f"Tamaño posicion: {t.get('cantidad','N/A')} unidades")
    print(f"Valor posicion: ${t.get('valor_posicion_usd','N/A')}")
    print(f"Riesgo: ${t.get('riesgo_usd','N/A')} ({t.get('porcentaje_capital','N/A')}% del capital)")
# Out:
# === TENDENCIAS MAYORES ===
# [filtro_tendencia] Analizando BTCUSDT...
# [filtro_tendencia] Analizando ETHUSDT...
# [filtro_tendencia] Analizando SOLUSDT...
# [filtro_tendencia] Analizando BNBUSDT...
#
# BTCUSDT:
#   Tendencia mayor: ALCISTA
#   Votos alcista: 3 | bajista: 0
#   Alineada compra: True | venta: False
#   1hora: ALCISTA_FUERTE
#   4horas: ALCISTA_FUERTE
#   diario: ALCISTA_FUERTE
#
# ETHUSDT:
#   Tendencia mayor: ALCISTA
#   Votos alcista: 3 | bajista: 0
#   Alineada compra: True | venta: False
#   1hora: ALCISTA_FUERTE
#   4horas: ALCISTA_FUERTE
#   diario: ALCISTA_FUERTE
#
# SOLUSDT:
#   Tendencia mayor: ALCISTA
#   Votos alcista: 3 | bajista: 0
#   Alineada compra: True | venta: False
#   1hora: ALCISTA_FUERTE
#   4horas: ALCISTA_FUERTE
#   diario: ALCISTA_FUERTE
#
# BNBUSDT:
#   Tendencia mayor: ALCISTA
#   Votos alcista: 3 | bajista: 0
#   Alineada compra: True | venta: False
#   1hora: ALCISTA_FUERTE
#   4horas: ALCISTA_FUERTE
#   diario: ALCISTA_FUERTE
#
# ...

# %%
import importlib
import agente_financiero.gestion_riesgo as gr
importlib.reload(gr)

from agente_financiero.gestion_riesgo import GestorRiesgo
gestor_nuevo = GestorRiesgo()

señal_prueba = {
    "simbolo":         "BTCUSDT",
    "precio":          81400.0,
    "stop_loss":       81200.0,
    "take_profit_1":   81800.0,
    "confianza_final": 85,
    "confluencia":     "ALTA",
    "señal_final":     "COMPRAR"
}

validacion = gestor_nuevo.validar_señal(señal_prueba)
print(f"Aprobada: {validacion['aprobada']}")
print(f"Errores: {validacion['errores']}")
if validacion.get('tamaño'):
    t = validacion['tamaño']
    print(f"Cantidad: {t.get('cantidad','N/A')} BTC")
    print(f"Valor posicion: ${t.get('valor_posicion_usd','N/A')}")
    print(f"Riesgo: ${t.get('riesgo_usd','N/A')} ({t.get('porcentaje_capital','N/A')}% capital)")
# Out:
# Aprobada: True
# Errores: []
# Cantidad: 0.2457 BTC
# Valor posicion: $20000.0
# Riesgo: $1000.0 (20.0% capital)

# %%
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

# Prueba horario
from agente_financiero.horario_trading import obtener_sesion_actual, debe_operar, proxima_sesion_optima

sesion = obtener_sesion_actual()
decision = debe_operar()

print("=== HORARIO DE TRADING ===")
print(f"Hora UTC: {sesion['hora_utc']}:00")
print(f"Score sesion: {sesion['score_sesion']}/10")
print(f"Recomendacion: {sesion['recomendacion']}")
print(f"Operar ahora: {decision['operar']}")
if decision['operar']:
    print(f"Agresividad: {decision['agresividad']}")
    print(f"Max operaciones: {decision['max_operaciones']}")
print(f"Proxima sesion optima: {proxima_sesion_optima()}")

# Prueba backtesting rapido
print("\n=== BACKTESTING RAPIDO BTC (3 dias) ===")
from agente_financiero.backtesting import backtest_rapido

resultado = backtest_rapido("BTCUSDT", dias=3)
print(f"Total operaciones: {resultado.get('total_operaciones', 0)}")
print(f"Win rate: {resultado.get('win_rate', 0)}%")
print(f"PnL total: {resultado.get('pnl_total_pct', 0)}%")
print(f"Profit factor: {resultado.get('profit_factor', 0)}")
print(f"Avg ganancia: {resultado.get('avg_win_pct', 0)}%")
print(f"Avg perdida: {resultado.get('avg_loss_pct', 0)}%")

# Prueba logger
print("\n=== LOGGER ===")
from agente_financiero.logger_trading import log_señal, obtener_estadisticas_dia

log_señal(
    simbolo="BTCUSDT", accion="COMPRAR", precio=81400.0,
    sl=81200.0, tp1=81800.0, tp2=82000.0, confianza=85.0,
    fuentes=["velas", "indicadores", "orderflow"],
    razon="Test de logging", horizonte="15min",
    aprobada_riesgo=True, aprobada_tendencia=True,
    tamaño_posicion={"cantidad": 0.245, "valor_posicion_usd": 20000, "riesgo_usd": 1000}
)

stats = obtener_estadisticas_dia()
print(f"Señales hoy: {stats.get('total_señales', 0)}")
print(f"Win rate hoy: {stats.get('win_rate', 0)}%")
print(f"PnL hoy: ${stats.get('pnl_total_usd', 0)}")
# Out:
# === HORARIO DE TRADING ===
# Hora UTC: 20:00
# Score sesion: 7/10
# Recomendacion: BUENA — hora de alta actividad
# Operar ahora: True
# Agresividad: ALTA
# Max operaciones: 2
# Proxima sesion optima: 21:00 UTC
#
# === BACKTESTING RAPIDO BTC (3 dias) ===
# [backtesting] Backtest rapido BTCUSDT ultimos 3 dias...
# C:\Users\Oscar Hernandez\agente_env\Lib\site-packages\numpy\_core\fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Oscar Hernandez\agente_env\Lib\site-packages\numpy\_core\_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Total operaciones: 25
# Win rate: 48.0%
# PnL total: 3.742%
# Profit factor: 3.09
# Avg ganancia: 0.461%
# Avg perdida: -0.138%
#
# === LOGGER ===
# [logger] Señal registrada: COMPRAR BTCUSDT @ 81400.0 | confianza=85.0%
# Señales hoy: 1
# Win rate hoy: 0%
# PnL hoy: $0

# %%
import importlib
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico
from agente_financiero.digestor_riesgo import ejecutar_digestor_riesgo

# Paso 1: Obtener señales del ciclo tecnico
print("=== PASO 1: CICLO TECNICO ===")
ciclo = await ejecutar_ciclo_tecnico()

# Paso 2: Filtrar por riesgo
print("\n=== PASO 2: FILTRO DE RIESGO ===")
resultado = await ejecutar_digestor_riesgo(ciclo['tabla'])

print(f"\nOperar: {resultado['operar']}")
print(f"Señales aprobadas: {len(resultado['señales_aprobadas'])}")
print(f"Señales rechazadas: {len(resultado['señales_rechazadas'])}")

if resultado['señales_aprobadas']:
    print("\n=== SEÑALES LISTAS PARA EJECUTAR ===")
    for s in resultado['señales_aprobadas']:
        t = s.get('tamaño_posicion', {})
        print(f"\n{s['simbolo']}: {s['accion']}")
        print(f"  Precio: {s['precio']}")
        print(f"  Cantidad: {t.get('cantidad','N/A')}")
        print(f"  Valor: ${t.get('valor_posicion_usd','N/A')}")
        print(f"  Riesgo: ${t.get('riesgo_usd','N/A')}")

print(f"\n=== CONFIRMACION IA ===")
print(resultado['confirmacion_ia'])

print(f"\n=== ESTADISTICAS DEL DIA ===")
stats = resultado['estadisticas_dia']
print(f"Señales hoy: {stats.get('total_señales',0)}")
print(f"Win rate: {stats.get('win_rate',0)}%")
print(f"PnL: ${stats.get('pnl_total_usd',0)}")
# Out:
# === PASO 1: CICLO TECNICO ===
#
# [digestor_tecnico] Ciclo tecnico 14:30:43
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/5] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [3/5] Analizando order flow...
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
# [4/5] Analizando niveles clave...
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
# [agente_niveles] Analizando ETHUSDT diario...
# ...

# %%
import importlib
import agente_financiero.gestion_riesgo as gr
import agente_financiero.digestor_riesgo as dr
importlib.reload(gr)
importlib.reload(dr)

from agente_financiero.digestor_tecnico import ejecutar_ciclo_tecnico
from agente_financiero.digestor_riesgo import ejecutar_digestor_riesgo

ciclo = await ejecutar_ciclo_tecnico()
resultado = await ejecutar_digestor_riesgo(ciclo['tabla'])

print(f"Señales aprobadas: {len(resultado['señales_aprobadas'])}")
print(f"Señales rechazadas: {len(resultado['señales_rechazadas'])}")

for s in resultado['señales_aprobadas']:
    t = s.get('tamaño_posicion', {})
    print(f"\n{s['simbolo']}: {s['accion']} @ {s['precio']}")
    print(f"  Cantidad: {t.get('cantidad','N/A')} | Valor: ${t.get('valor_posicion_usd','N/A')} | Riesgo: ${t.get('riesgo_usd','N/A')}")

print(f"\nConfirmacion: {resultado['confirmacion_ia']}")
# Out:
# [digestor_tecnico] Ciclo tecnico 14:51:07
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# [2/5] Calculando indicadores avanzados...
# [agente_indicadores] Procesando BTCUSDT...
# [agente_indicadores] Procesando ETHUSDT...
# [agente_indicadores] Procesando SOLUSDT...
# [agente_indicadores] Procesando BNBUSDT...
# [3/5] Analizando order flow...
# [agente_orderflow] Analizando BTCUSDT...
# [agente_orderflow] Analizando ETHUSDT...
# [agente_orderflow] Analizando SOLUSDT...
# [agente_orderflow] Analizando BNBUSDT...
# [4/5] Analizando niveles clave...
# [agente_niveles] Analizando BTCUSDT diario...
# [agente_niveles] Analizando BTCUSDT 4h...
# [agente_niveles] Analizando ETHUSDT diario...
# [agente_niveles] Analizando ETHUSDT 4h...
# ...

# %%
from agente_financiero.agente_funding import analizar_funding_completo

resultados = analizar_funding_completo()

for r in resultados:
    if "error" not in r:
        print(f"\n{'='*50}")
        print(f"SIMBOLO: {r['simbolo']}")
        print(f"Funding rate: {r['funding']['funding_rate']}% | APY: {r['funding']['funding_8h_pct']}%")
        print(f"Señal funding: {r['funding']['señal']}")
        print(f"Open Interest: {r['open_interest']['señal']}")
        print(f"Confluencia: {r['confluencia']}")
        print(f"ACCION: {r['accion']} | Fuerza: {r['fuerza']}")
# Out:
# [agente_funding] Analizando BTCUSDT...
# [agente_funding] Analizando ETHUSDT...
# [agente_funding] Analizando SOLUSDT...
# [agente_funding] Analizando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT
# Funding rate: 0.0061% | APY: 6.69%
# Señal funding: NEUTRAL — funding equilibrado
# Open Interest: ESTABLE
# Confluencia: MIXTA — NEUTRAL — funding equilibrado
# ACCION: ESPERAR | Fuerza: baja
#
# ...
# SIMBOLO: ETHUSDT
# Funding rate: 0.0096% | APY: 10.49%
# Señal funding: NEUTRAL — funding equilibrado
# Open Interest: CAYENDO_FUERTE — liquidaciones o cierres masivos
# Confluencia: MIXTA — NEUTRAL — funding equilibrado
# ACCION: ESPERAR | Fuerza: baja
#
# ...
# SIMBOLO: SOLUSDT
# Funding rate: 0.0095% | APY: 10.41%
# Señal funding: NEUTRAL — funding equilibrado
# Open Interest: CAYENDO_FUERTE — liquidaciones o cierres masivos
# Confluencia: MIXTA — NEUTRAL — funding equilibrado
# ACCION: ESPERAR | Fuerza: baja
#
# ...
# SIMBOLO: BNBUSDT
# Funding rate: 0.0106% | APY: 11.6%
# ...

# %%
from agente_financiero.agente_liquidaciones import analizar_liquidaciones_completo

resultados = analizar_liquidaciones_completo()

for r in resultados:
    if "error" not in r:
        liq  = r["liquidaciones"]
        mapa = r["mapa"]
        print(f"\n{'='*50}")
        print(f"SIMBOLO: {r['simbolo']} | PRECIO: {mapa.get('precio_actual','N/A')}")
        print(f"Señal: {liq.get('señal','N/A')}")
        print(f"Longs liquidados: {liq.get('longs_liquidados',0)} | Vol: ${liq.get('vol_longs_usd',0):,.0f}")
        print(f"Shorts liquidados: {liq.get('shorts_liquidados',0)} | Vol: ${liq.get('vol_shorts_usd',0):,.0f}")
        print(f"Contexto mapa: {r['contexto']}")
        print(f"Soporte institucional: {mapa.get('soporte_institucional','N/A')} ({mapa.get('dist_soporte_pct','N/A')}% abajo)")
        print(f"Resistencia institucional: {mapa.get('resistencia_institucional','N/A')} ({mapa.get('dist_resistencia_pct','N/A')}% arriba)")
# Out:
# [agente_liquidaciones] Analizando BTCUSDT...
# [agente_liquidaciones] Analizando ETHUSDT...
# [agente_liquidaciones] Analizando SOLUSDT...
# [agente_liquidaciones] Analizando BNBUSDT...

# %%
import importlib
import agente_financiero.agente_liquidaciones as al
importlib.reload(al)

resultados = al.analizar_liquidaciones_completo()

for r in resultados:
    if "error" not in r:
        ls   = r["long_short"]
        taker = r["taker"]
        mapa  = r["mapa"]
        print(f"\n{'='*50}")
        print(f"SIMBOLO: {r['simbolo']} | PRECIO: {mapa.get('precio_actual','N/A')}")
        print(f"Longs: {ls.get('longs_pct','N/A')}% | Shorts: {ls.get('shorts_pct','N/A')}%")
        print(f"Señal L/S: {ls.get('señal','N/A')}")
        print(f"Taker ratio: {taker.get('taker_ratio','N/A')} | {taker.get('señal','N/A')}")
        print(f"Contexto mapa: {mapa.get('contexto','N/A')}")
        print(f"Soporte: {mapa.get('soporte','N/A')} ({mapa.get('dist_soporte_pct','N/A')}% abajo)")
        print(f"Resistencia: {mapa.get('resistencia','N/A')} ({mapa.get('dist_resist_pct','N/A')}% arriba)")
        print(f"SEÑAL FINAL: {r['señal_final']} | votos C={r['votos_compra']} V={r['votos_venta']}")
# Out:
# [agente_liquidaciones] Analizando BTCUSDT...
# [agente_liquidaciones] Analizando ETHUSDT...
# [agente_liquidaciones] Analizando SOLUSDT...
# [agente_liquidaciones] Analizando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT | PRECIO: 80625.0066
# Longs: 40.16% | Shorts: 59.84%
# Señal L/S: SHORTS_DOMINANDO — sesgo bajista moderado
# Taker ratio: 0.953 | EQUILIBRADO
# Contexto mapa: EN_SOPORTE_FUERTE — rebote probable
# Soporte: 80621.5 (0.004% abajo)
# Resistencia: 80621.6 (-0.004% arriba)
# SEÑAL FINAL: ESPERAR | votos C=1 V=1
#
# ...
# SIMBOLO: ETHUSDT | PRECIO: 2324.16
# Longs: 66.31% | Shorts: 33.69%
# Señal L/S: EXCESO_LONGS — mercado sobrecalentado alcista, posible caida
# Taker ratio: 1.06 | EQUILIBRADO
# Contexto mapa: EN_SOPORTE_FUERTE — rebote probable
# Soporte: 2324.65 (-0.021% abajo)
# Resistencia: 2324.66 (0.022% arriba)
# SEÑAL FINAL: ESPERAR | votos C=1 V=1
#
# ...
# SIMBOLO: SOLUSDT | PRECIO: 94.7443
# Longs: 57.4% | Shorts: 42.6%
# Señal L/S: LONGS_DOMINANDO — sesgo alcista moderado
# ...

# %%
from agente_financiero.agente_estructura import analizar_estructura_completo

resultados = analizar_estructura_completo()

for r in resultados:
    if "error" not in r:
        print(f"\n{'='*50}")
        print(f"SIMBOLO: {r['simbolo']} | PRECIO: {r['precio']}")
        print(f"Estructura principal: {r['estructura']}")
        print(f"BOS: {r.get('bos', 'ninguno')}")
        print(f"CHoCH: {r.get('choch', 'ninguno')}")
        print(f"Timeframes: {r['timeframes']}")
        print(f"Señales TF: {r['señales_tf']}")
        print(f"Zona liquidez arriba: {r['zona_liq_arriba']} ({r['dist_liq_arriba']}%)")
        print(f"Zona liquidez abajo: {r['zona_liq_abajo']} ({r['dist_liq_abajo']}%)")
        print(f"SEÑAL: {r['señal_final']} | Confluencia: {r['confluencia']} | C={r['votos_compra']} V={r['votos_venta']}")
# Out:
# [agente_estructura] Analizando BTCUSDT...
# [agente_estructura] Analizando ETHUSDT...
# [agente_estructura] Analizando SOLUSDT...
# [agente_estructura] Analizando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT | PRECIO: 80759.99
# Estructura principal: LATERAL
# BOS: None
# CHoCH: None
# Timeframes: {'5m': 'TENDENCIA_BAJISTA', '15m': 'LATERAL', '1h': 'TENDENCIA_ALCISTA'}
# Señales TF: {'5m': 'VENDER', '15m': 'ESPERAR', '1h': 'COMPRAR'}
# Zona liquidez arriba: 81583.11 (1.019%)
# Zona liquidez abajo: 80691.0 (0.085%)
# SEÑAL: ESPERAR | Confluencia: BAJA | C=1 V=1
#
# ...
# SIMBOLO: ETHUSDT | PRECIO: 2329.79
# Estructura principal: TENDENCIA_ALCISTA
# BOS: None
# CHoCH: None
# Timeframes: {'5m': 'TENDENCIA_BAJISTA', '15m': 'TENDENCIA_ALCISTA', '1h': 'TENDENCIA_ALCISTA'}
# Señales TF: {'5m': 'VENDER', '15m': 'COMPRAR', '1h': 'COMPRAR'}
# Zona liquidez arriba: 2369.86 (1.72%)
# Zona liquidez abajo: 2319.0 (0.463%)
# SEÑAL: COMPRAR | Confluencia: MEDIA | C=2 V=1
#
# ...
# SIMBOLO: SOLUSDT | PRECIO: 94.84
# ...

# %%
from agente_financiero.agente_volume_profile import analizar_volume_profile_completo

resultados = analizar_volume_profile_completo()

for r in resultados:
    if "error" not in r:
        vp1 = r["vp_1h"]
        vp4 = r["vp_4h"]
        print(f"\n{'='*50}")
        print(f"SIMBOLO: {r['simbolo']} | PRECIO: {vp1['precio_actual']}")
        print(f"--- 1H ---")
        print(f"POC: {vp1['poc']} ({vp1['dist_poc_pct']}% del precio)")
        print(f"VAH: {vp1['vah']} ({vp1['dist_vah_pct']}%) | VAL: {vp1['val']} ({vp1['dist_val_pct']}%)")
        print(f"Posicion: {vp1['posicion']}")
        print(f"HVN cercano: {vp1.get('hvn_cercano','N/A')} | LVN cercano: {vp1.get('lvn_cercano','N/A')}")
        print(f"--- 4H ---")
        print(f"POC: {vp4['poc']} | Posicion: {vp4['posicion'][:40]}")
        print(f"SEÑAL: {r['señal_final']} | Confluencia: {r['confluencia']}")
# Out:
# [agente_vp] Analizando BTCUSDT...
# [agente_vp] Analizando ETHUSDT...
# [agente_vp] Analizando SOLUSDT...
# [agente_vp] Analizando BNBUSDT...
#
# ...
# SIMBOLO: BTCUSDT | PRECIO: 80760.53
# --- 1H ---
# POC: 80228.744 (-0.658% del precio)
# VAH: 81499.656 (0.915%) | VAL: 79593.288 (1.445%)
# Posicion: DENTRO_VA — precio en zona de valor normal
# HVN cercano: 80864.2 | LVN cercano: 81976.248
# --- 4H ---
# POC: 78234.3867 | Posicion: DENTRO_VA — precio en zona de valor norm
# SEÑAL: ESPERAR | Confluencia: BAJA
#
# ...
# SIMBOLO: ETHUSDT | PRECIO: 2331.93
# --- 1H ---
# POC: 2331.4975 (-0.019% del precio)
# VAH: 2378.9365 (2.016%) | VAL: 2284.0585 (2.053%)
# Posicion: EN_POC — zona de mayor equilibrio, esperar ruptura
# HVN cercano: 2331.4975 | LVN cercano: 2273.5165
# --- 4H ---
# POC: 2318.6603 | Posicion: DENTRO_VA — precio en zona de valor norm
# SEÑAL: ESPERAR | Confluencia: BAJA
#
# ...
# SIMBOLO: SOLUSDT | PRECIO: 95.15
# --- 1H ---
# POC: 84.8365 (-10.839% del precio)
# ...

# %%
from agente_financiero.digestor_tecnico_avanzado import ejecutar_ciclo_avanzado

resultado = await ejecutar_ciclo_avanzado()

print(f"Modelo: {resultado['modelo']}")
print(f"Señales fuertes: {len(resultado['señales_fuertes'])}")

print(f"\n=== TABLA AVANZADA ===")
for t in resultado['tabla']:
    print(f"\n{t['simbolo']}: {t['señal_final']} | conf={t['confianza']}% | {t['confluencia']}")
    print(f"  Votos C={t['votos_compra']} V={t['votos_venta']}")
    print(f"  Funding={t['señal_funding']} | Liq={t['señal_liq']} | Estructura={t['señal_estructura']} | VP={t['señal_vp']}")
    print(f"  POC={t['poc']} | VAH={t['vah']} | VAL={t['val']}")

print(f"\n=== DECISIONES AVANZADAS ===")
print(resultado['decisiones'])
# Out:
# [digestor_avanzado] Ciclo avanzado 15:40:40
# [1/4] Analizando funding rate y OI...
# [agente_funding] Analizando BTCUSDT...
# [agente_funding] Analizando ETHUSDT...
# [agente_funding] Analizando SOLUSDT...
# [agente_funding] Analizando BNBUSDT...
# [2/4] Analizando liquidaciones y long/short...
# [agente_liquidaciones] Analizando BTCUSDT...
# [agente_liquidaciones] Analizando ETHUSDT...
# [agente_liquidaciones] Analizando SOLUSDT...
# [agente_liquidaciones] Analizando BNBUSDT...
# [3/4] Analizando estructura de mercado...
# [agente_estructura] Analizando BTCUSDT...
# [agente_estructura] Analizando ETHUSDT...
# [agente_estructura] Analizando SOLUSDT...
# [agente_estructura] Analizando BNBUSDT...
# [4/4] Calculando volume profile...
# [agente_vp] Analizando BTCUSDT...
# [agente_vp] Analizando ETHUSDT...
# [agente_vp] Analizando SOLUSDT...
# [agente_vp] Analizando BNBUSDT...
# [digestor_avanzado] Generando analisis con IA...
# [cliente_ia] Claude no disponible, usando Ollama...
# ...

# %%
import importlib
import agente_financiero.digestor_maestro as dm
importlib.reload(dm)

from agente_financiero.digestor_maestro import ejecutar_ciclo_maestro
resultado = await ejecutar_ciclo_maestro()
# Out:
# ...
# [MAESTRO] Ciclo maestro iniciado: 16:36:17
# ...
# [MAESTRO] Horario: BAJA — poca actividad | Score: 3/10
#
# [MAESTRO] Ejecutando ciclos técnico y avanzado en paralelo...
#
# [digestor_tecnico] Ciclo tecnico 16:36:17
# [1/5] Analizando velas japonesas...
# [agente_velas] Analizando BTCUSDT...
# [agente_velas] Analizando ETHUSDT...
# [agente_velas] Analizando SOLUSDT...
# [agente_velas] Analizando BNBUSDT...
# [agente_velas] Generando recomendaciones con IA...
#
# [digestor_avanzado] Ciclo avanzado 16:36:21
# [1/4] Analizando funding rate y OI...
# [agente_funding] Analizando BTCUSDT...
# [agente_funding] Analizando ETHUSDT...
# [agente_funding] Analizando SOLUSDT...
# [agente_funding] Analizando BNBUSDT...
# [2/4] Analizando liquidaciones y long/short...
# [agente_liquidaciones] Analizando BTCUSDT...
# [agente_liquidaciones] Analizando ETHUSDT...
# [agente_liquidaciones] Analizando SOLUSDT...
# [agente_liquidaciones] Analizando BNBUSDT...
# [3/4] Analizando estructura de mercado...
# ...

# %%
print(f"Duracion: {resultado['duracion_segundos']}s")
print(f"Modelo: {resultado['modelo']}")
print(f"Señales fuertes: {len(resultado['señales_fuertes'])}")
print(f"Señales aprobadas: {len(resultado['señales_aprobadas'])}")

print(f"\n=== TABLA MAESTRA ===")
for t in resultado['tabla_maestra']:
    print(f"{t['simbolo']}: {t['señal_maestra']} | conf={t['confianza_final']}% | {t['confluencia']}")

print(f"\n=== DECISION MAESTRA ===")
print(resultado['decision_maestra'])
# Out:
# Duracion: 391.3s
# Modelo: llama3.2
# Señales fuertes: 1
# Señales aprobadas: 1
#
# === TABLA MAESTRA ===
# BTCUSDT: VENDER | conf=62% | MEDIA
# ETHUSDT: VENDER | conf=69% | MEDIA
# SOLUSDT: COMPRAR | conf=93% | MUY_ALTA
# BNBUSDT: VENDER | conf=59% | MEDIA
#
# === DECISION MAESTRA ===
# DECISION_MAESTRA_1:
# - ACCION: COMPRAR
# - SIMBOLO: SOLUSDT
# - PRECIO_ENTRADA: 95.98
# - STOP_LOSS: 94.9818
# - TAKE_PROFIT_1: 97.9764
# - TAKE_PROFIT_2: no establecido
# - CONFIANZA_SISTEMA: 93%
# - SISTEMAS_CONFIRMACION: avanzado
# - RAZON_MAESTRA: La alza continua sin precedentes y la confianza del sistema es muy alta, lo que indica una oportunidad de compra segura. El precio está a punto de superar el nivel de resistencia en 97.9764.
# - HORIZONTE: H1
# - PRIORIDAD: 1

# %%
import requests



TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates")

print(r.json())
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Envia mensaje de prueba primero
r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?offset=-1")
data = r.json()
print(data)

if data.get("result"):
    chat_id = data["result"][0]["message"]["chat"]["id"]
    print(f"\nTu Chat ID es: {chat_id}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Primero limpia el webhook si existe
requests.get(f"https://api.telegram.org/bot{TOKEN}/deleteWebhook")

# Luego obtiene updates
r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?allowed_updates=message&limit=10")
data = r.json()
print(data)
# Out:
# {'ok': True, 'result': []}

# %%
import importlib
import sys
sys.path.insert(0, r'C:\Users\Oscar Hernandez\agente-ia')

from dotenv import load_dotenv
load_dotenv(r'C:\Users\Oscar Hernandez\.env', override=True)

from agente_financiero.alertas_telegram import enviar_mensaje, alerta_señal

# Prueba mensaje simple
enviar_mensaje("🤖 Sistema de Trading IA conectado correctamente")
# Out:
# False

# %%
import requests
import os

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = "6956192968"

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "Sistema de Trading IA conectado"}
)
print(r.status_code)
print(r.json())
# Out:
# 400
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates")
data = r.json()
print(data)
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = 6956192968  # número sin comillas

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "Sistema de Trading IA conectado"}
)
print(r.status_code)
print(r.json())
# Out:
# 400
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Obtiene el update mas reciente
r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=1&offset=-1&timeout=5")
data = r.json()
print(data)

if data.get("result"):
    chat_id = data["result"][0]["message"]["chat"]["id"]
    print(f"\nChat ID encontrado: {chat_id}")
    
    # Intenta enviar mensaje inmediatamente
    r2 = requests.post(
        f"https://api.telegram.org/bot{TOKEN}/sendMessage",
        json={"chat_id": chat_id, "text": "Bot conectado exitosamente!"}
    )
    print(r2.json())
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=10&timeout=0")
print(r.text)
# Out:
# {"ok":true,"result":[]}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=10&timeout=0")
print(r.text)
# Out:
# {"ok":true,"result":[]}

# %%
import requests, time
TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
for i in range(5):
    r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5&timeout=2")
    data = r.json()
    if data.get("result"):
        print("ENCONTRADO:", data)
        break
    print(f"Intento {i+1}: vacío")
    time.sleep(1)
# Out:
# Intento 1: vacío
# Intento 2: vacío
# Intento 3: vacío
# Intento 4: vacío
# Intento 5: vacío

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = 6956192968

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "Test"}
)
print(r.json())
# Out:
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = 6956192968

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "Test"}
)
print(r.json())
# Out:
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests, threading, time

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
chat_id_encontrado = None

def escuchar():
    global chat_id_encontrado
    offset = 0
    for _ in range(30):  # espera 30 segundos
        r = requests.get(
            f"https://api.telegram.org/bot{TOKEN}/getUpdates",
            params={"offset": offset, "timeout": 1, "limit": 5}
        )
        updates = r.json().get("result", [])
        for u in updates:
            offset = u["update_id"] + 1
            if "message" in u:
                chat_id_encontrado = u["message"]["chat"]["id"]
                print(f"CHAT ID ENCONTRADO: {chat_id_encontrado}")
                return
        time.sleep(1)

t = threading.Thread(target=escuchar)
t.start()
print("Esperando mensaje... Envía cualquier mensaje al bot en Telegram AHORA")
t.join()
print(f"Tu Chat ID es: {chat_id_encontrado}")
# Out:
# Esperando mensaje... Envía cualquier mensaje al bot en Telegram AHORA
# Tu Chat ID es: None

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Obtiene info del bot para verificar que el token es correcto
r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getMe")
print(r.json())
# Out:
# {'ok': True, 'result': {'id': 8547644135, 'is_bot': True, 'first_name': 'AgenteIA Trading', 'username': 'agente_ia_trading_bot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'supports_guest_queries': False, 'can_connect_to_business': False, 'has_main_web_app': False, 'has_topics_enabled': False, 'allows_users_to_create_topics': False, 'can_manage_bots': False}}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=5")
data = r.json()
print(data)

if data.get("result"):
    for update in data["result"]:
        if "message" in update:
            chat_id = update["message"]["chat"]["id"]
            chat_type = update["message"]["chat"]["type"]
            print(f"\nChat ID: {chat_id} | Tipo: {chat_type}")
# Out:
# {'ok': True, 'result': []}

# %%
import requests

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Obtiene info del bot
bot_info = requests.get(f"https://api.telegram.org/bot{TOKEN}/getMe").json()
print(f"Bot ID: {bot_info['result']['id']}")

# El Chat ID del grupo es negativo y empieza con -100
# Basado en lo que vimos, tu grupo probablemente tiene este formato
# Vamos a intentar con el ID de usuario que ya tenemos
chat_id = -6956192968  # grupos tienen ID negativo

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": chat_id, "text": "test grupo"}
)
print(r.json())
# Out:
# Bot ID: 8547644135
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = -4999471159

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "🤖 Sistema de Trading IA conectado correctamente"}
)
print(r.json())
# Out:
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = -1004999471159

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "🤖 Sistema de Trading IA conectado"}
)
print(r.json())
# Out:
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests, time

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

# Escucha por 15 segundos
print("Enviando mensaje al grupo AHORA y esperando...")
for i in range(15):
    r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=10&timeout=1")
    updates = r.json().get("result", [])
    if updates:
        for u in updates:
            msg = u.get("message", {})
            chat = msg.get("chat", {})
            print(f"Chat ID: {chat.get('id')} | Tipo: {chat.get('type')} | Titulo: {chat.get('title')}")
        break
    time.sleep(1)
    print(f"Intento {i+1}...")
# Out:
# Enviando mensaje al grupo AHORA y esperando...
# Intento 1...
# Intento 2...
# Intento 3...
# Intento 4...
# Intento 5...
# Intento 6...
# Intento 7...
# Intento 8...
# Intento 9...
# Intento 10...
# Intento 11...
# Intento 12...
# Intento 13...
# Intento 14...
# Intento 15...

# %%
import requests, time

TOKEN = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"

print("Enviando mensaje al grupo AHORA...")
for i in range(20):
    r = requests.get(f"https://api.telegram.org/bot{TOKEN}/getUpdates?limit=10&timeout=1&allowed_updates=message,channel_post")
    updates = r.json().get("result", [])
    if updates:
        for u in updates:
            print(f"Update completo: {u}")
        break
    time.sleep(1)
    print(f"Intento {i+1}...")
# Out:
# Enviando mensaje al grupo AHORA...
# Intento 1...
# Intento 2...
# Intento 3...
# Intento 4...
# Intento 5...
# Intento 6...
# Intento 7...
# Intento 8...
# Intento 9...
# Intento 10...
# Intento 11...
# Intento 12...
# Intento 13...
# Intento 14...
# Intento 15...
# Intento 16...
# Intento 17...
# Intento 18...
# Intento 19...
# Intento 20...

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = -4999471159

# Intenta enviar mensaje del bot al grupo
r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={
        "chat_id": CHAT_ID,
        "text": "🤖 Sistema de Trading IA conectado"
    }
)
print(r.status_code)
print(r.json())
# Out:
# 400
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = -100_4999471159

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "🤖 Sistema de Trading IA conectado"}
)
print(r.status_code)
print(r.json())
# Out:
# 400
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}

# %%
import requests

TOKEN   = "8547644135:AAG10HHu6ctQmjJSsEhW7xaxLMs1wfARTQw"
CHAT_ID = -100_4999471159

r = requests.post(
    f"https://api.telegram.org/bot{TOKEN}/sendMessage",
    json={"chat_id": CHAT_ID, "text": "🤖 Sistema de Trading IA conectado"}
)
print(r.status_code)
print(r.json())
# Out:
# 400
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat not found'}
