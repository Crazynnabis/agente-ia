# %%
import ollama

respuesta = ollama.chat(
    model="llama3.2",
    messages=[
        {"role": "user", "content": "Responde solo esto: Ollama conectado correctamente al proyecto"}
    ]
)

print(respuesta['message']['content'])
# Out:
# Excelente, ahora puedes utilizar la función.
